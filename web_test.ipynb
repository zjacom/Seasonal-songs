# %%
# 이 코드 참고하시면 좋을 것 같아요 하영님!

import requests
from bs4 import BeautifulSoup



if __name__ == "__main__":
    RANK = 100 ## 멜론 차트 순위가 1 ~ 100위까지 있음

    header = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko'}
    req = requests.get('https://www.melon.com/chart/week/index.htm', headers = header) ## 주간 차트를 크롤링 할 것임
    html = req.text
    parse = BeautifulSoup(html, 'html.parser')

    titles = parse.find_all("div", {"class": "ellipsis rank01"}) 
    singers = parse.find_all("div", {"class": "ellipsis rank02"}) 
    albums = parse.find_all("div",{"class": "ellipsis rank03"}) 
    title = []
    singer = []
    album = []

    for t in titles:
        title.append(t.find('a').text) 
    for s in singers:
        singer.append(s.find('span', {"class": "checkEllipsis"}).text)

    for a in albums:
        album.append(a.find('a').text)

    for i in range(RANK):
        print('%3d위: %s [ %s ] - %s'%(i+1, title[i], album[i], singer[i]))
# Out:
#   1위: Magnetic [ SUPER REAL ME ] - 아일릿(ILLIT)
#   2위: 나는 아픈 건 딱 질색이니까 [ 2 ] - (여자)아이들
#   3위: 첫 만남은 계획대로 되지 않아 [ TWS 1st Mini Album ‘Sparkling Blue’ ] - TWS (투어스)
#   4위: 밤양갱 [ 밤양갱 ] - 비비 (BIBI)
#   5위: Love wins all [ The Winning ] - 아이유
#   6위: 천상연 [ 천상연 (웹툰 '선녀외전' X 이창섭 (LEE CHANGSUB)) ] - 이창섭
#   7위: EASY [ EASY ] - LE SSERAFIM (르세라핌)
#   8위: Smart [ EASY ] - LE SSERAFIM (르세라핌)
#   9위: 비의 랩소디 [ 비의 랩소디 ] - 임재현
#  10위: To. X [ To. X - The 5th Mini Album ] - 태연 (TAEYEON)
#  11위: 예뻤어 [ Every DAY6 February ] - DAY6 (데이식스)
#  12위: 한 페이지가 될 수 있게 [ The Book of Us : Gravity ] - DAY6 (데이식스)
#  13위: 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection)) [ 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection)) ] - 너드커넥션 (Nerd Connection)
#  14위: Love 119 [ Love 119 ] - RIIZE
#  15위: Perfect Night [ Perfect Night ] - LE SSERAFIM (르세라핌)
#  16위: 홀씨 [ The Winning ] - 아이유
#  17위: 헤어지자 말해요 [ 1집 Alone ] - 박재정
#  18위: 에피소드 [ 에피소드 ] - 이무진
#  19위: Drama [ Drama - The 4th Mini Album ] - aespa
#  20위: 인사 [ 인사 ] - 범진
#  21위: I AM [ I've IVE ] - IVE (아이브)
#  22위: Seven (feat. Latto) - Clean Ver. [ Seven (feat. Latto) - Clean Ver. ] - 정국
#  23위: 사랑인가 봐 [ 사랑인가 봐 (사내맞선 OST 스페셜 트랙) ] - 멜로망스
#  24위: MANIAC [ The 4th Mini Album 'VERSUS' ] - VIVIZ (비비지)
#  25위: 꿈 [ 웰컴투 삼달리 OST Part.3 ] - 태연 (TAEYEON)
#  26위: 너의 모든 순간 [ 별에서 온 그대 OST Part.7 ] - 성시경
#  27위: Love Lee [ Love Lee ] - AKMU (악뮤)
#  28위: Hype Boy [ NewJeans 1st EP 'New Jeans' ] - NewJeans
#  29위: Super Lady [ 2 ] - (여자)아이들
#  30위: 사랑은 늘 도망가 [ 신사와 아가씨 OST Part.2 ] - 임영웅
#  31위: 사막에서 꽃을 피우듯 [ 사막에서 꽃을 피우듯 ] - 우디 (Woody)
#  32위: Super Shy [ NewJeans 2nd EP 'Get Up' ] - NewJeans
#  33위: Get A Guitar [ Get A Guitar ] - RIIZE
#  34위: 퀸카 (Queencard) [ I feel ] - (여자)아이들
#  35위: 주저하는 연인들을 위해 [ 전설 ] - 잔나비
#  36위: Welcome to the Show [ Fourever ] - DAY6 (데이식스)
#  37위: Siren [ Siren ] - RIIZE
#  38위: Wife [ 2 ] - (여자)아이들
#  39위: Ditto [ NewJeans 'OMG' ] - NewJeans
#  40위: 고민중독 [ 1st Mini Album 'MANITO' ] - QWER
#  41위: Shopper [ The Winning ] - 아이유
#  42위: 잘 지내자, 우리 (여름날 우리 X 로이킴) [ 잘 지내자, 우리 (여름날 우리 X 로이킴) ] - 로이킴
#  43위: 사건의 지평선 [ YOUNHA 6th Album Repackage 'END THEORY : Final Edition' ] - 윤하 (YOUNHA)
#  44위: Baddie [ I'VE MINE ] - IVE (아이브)
#  45위: 봄날 [ YOU NEVER WALK ALONE ] - 방탄소년단
#  46위: 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 [ 항해 ] - AKMU (악뮤)
#  47위: You & Me [ JENNIE Special Single [You & Me] ] - 제니 (JENNIE)
#  48위: ETA [ NewJeans 2nd EP 'Get Up' ] - NewJeans
#  49위: 벚꽃 엔딩 [ 버스커 버스커 1집 ] - 버스커 버스커
#  50위: 그대가 내 안에 박혔다(그내박) [ 그대가 내 안에 박혔다(그내박) ] - 순순희(기태)
#  51위: 봄 사랑 벚꽃 말고 [ 봄 사랑 벚꽃 말고 ] - HIGH4 (하이포), 아이유
#  52위: 사랑할 수밖에 [ Merry Go Round ] - 볼빨간사춘기
#  53위: 후라이의 꿈 [ Love Lee ] - AKMU (악뮤)
#  54위: 취중고백 [ 취중고백 ] - 김민석
#  55위: I Don't Think That I Like Her [ CHARLIE ] - Charlie Puth
#  56위: 심(心) [ 심(心) ] - DK(디셈버)
#  57위: 모든 날, 모든 순간 (Every day, Every Moment) [ '키스 먼저 할까요?' OST Part.3 ] - 폴킴
#  58위: 사랑하지 않아서 그랬어 [ 사랑하지 않아서 그랬어 ] - 임한별
#  59위: LOVE DIVE [ LOVE DIVE ] - IVE (아이브)
#  60위: 미안해 미워해 사랑해 [ 눈물의 여왕 OST Part.4 ] - Crush
#  61위: Spicy [ MY WORLD - The 3rd Mini Album ] - aespa
#  62위: 사랑..그게 뭔데 [ 사랑..그게 뭔데 ] - 지아
#  63위: 다정히 내 이름을 부르면 [ 다정히 내 이름을 부르면 (경서예지 x 전건호) ] - 경서예지, 전건호
#  64위: 해요 (2022) [ 해요 (2022) ] - #안녕
#  65위: Kitsch [ I've IVE ] - IVE (아이브)
#  66위: Steal The Show (From “엘리멘탈”) [ Steal The Show (From “엘리멘탈”) ] - Lauv
#  67위: 물론 [ 물론 ] - 허각
#  68위: 우리들의 블루스 [ IM HERO ] - 임영웅
#  69위: 혹시 세상에 혼자 남겨진 것 같다면 [ When You Alone ] - 우디 (Woody)
#  70위: 모래 알갱이 [ 모래 알갱이 ] - 임영웅
#  71위: 파이팅 해야지 (Feat. 이영지) [ 부석순 1st Single Album 'SECOND WIND' ] - 부석순 (SEVENTEEN)
#  72위: 기억해줘요 내 모든 날과 그때를 [ 기억해줘요 내 모든 날과 그때를 ] - 화곡동 청개구리
#  73위: Dynamite [ Dynamite (DayTime Version) ] - 방탄소년단
#  74위: 이브, 프시케 그리고 푸른 수염의 아내 [ UNFORGIVEN ] - LE SSERAFIM (르세라핌)
#  75위: 봄이 와도 [ 봄이 와도 ] - 로이킴
#  76위: 손오공 [ SEVENTEEN 10th Mini Album ‘FML' ] - 세븐틴 (SEVENTEEN)
#  77위: 별 떨어진다 (I Do) [ 기대 - The 2nd Mini Album ] - 디오 (D.O.)
#  78위: WAY 4 LUV [ ASTERUM : 134-1 ] - PLAVE
#  79위: 우연히 봄 [ 냄새를 보는 소녀 OST Part.2 ] - 로꼬, 유주 (YUJU)
#  80위: After LIKE [ After LIKE ] - IVE (아이브)
#  81위: Yes or No (Feat. 허윤진 of LE SSERAFIM, Crush) [ Yes or No ] - 그루비룸 (GroovyRoom)
#  82위: Dangerously [ Nine Track Mind (Deluxe Edition) ] - Charlie Puth
#  83위: Standing Next to You [ GOLDEN ] - 정국
#  84위: 다시 만날 수 있을까 [ IM HERO ] - 임영웅
#  85위: Deja Vu [ minisode 3: TOMORROW ] - 투모로우바이투게더
#  86위: 이제 나만 믿어요 [ 내일은 미스터트롯 우승자 특전곡 ] - 임영웅
#  87위: Do or Die [ Do or Die ] - 임영웅
#  88위: 영원 [ 영원 (남은 인생 10년 X DK(디셈버)) ] - DK(디셈버)
#  89위: 건물 사이에 피어난 장미 (Rose Blossom) [ H1-KEY 1st Mini Album [Rose Blossom] ] - H1-KEY (하이키)
#  90위: 무지개 [ IM HERO ] - 임영웅
#  91위: Smoothie [ DREAM( )SCAPE ] - NCT DREAM
#  92위: OMG [ NewJeans 'OMG' ] - NewJeans
#  93위: 개화 (Flowering) [ DEAR. ] - LUCY
#  94위: London Boy [ Polaroid ] - 임영웅
#  95위: Discord [ 1st Single Album 'Harmony from Discord' ] - QWER
#  96위: 아버지 [ IM HERO ] - 임영웅
#  97위: Polaroid [ Polaroid ] - 임영웅
#  98위: 좋아해요 [ 눈물의 여왕 OST Part.6 ] - 폴킴
#  99위: Attention [ NewJeans 1st EP 'New Jeans' ] - NewJeans
# 100위: 우리 영화 [ ASTERUM : 134-1 ] - PLAVE
